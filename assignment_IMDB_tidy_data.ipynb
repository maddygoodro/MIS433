# %% [markdown]
# <a href="https://colab.research.google.com/github/maddygoodro/MIS433/blob/main/assignment_IMDB_tidy_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment - Analyzing the IMDB Top 1000 Movies

# %% [markdown]
# In the next few assignments, you will be working with this data set of IMDB top 1000 movies.
#
# Source: https://www.kaggle.com/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows

# %%
import pandas as pd
import numpy as np

# %%
# Read the data file "imdb_top_1000.csv" to a dataframe named "imdb"
imdb = pd.read_csv('https://raw.githubusercontent.com/jiexunli-wwu/mis433/refs/heads/main/data/imdb_top_1000.csv', header=0)
imdb.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
# Number of rows?
# Number of columns?
imdb.shape
# Out:
# (1000, 16)

# %%
# Describe the dataframe using the info() method.
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
# Use describe() to summarize the descriptive statistics of *all* columns
imdb.describe(include='all')
# Out:
#                                               Poster_Link Series_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMTY5OD...     Drishyam
# freq                                                    1            2
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# ...

# %%
# List all the column names:
imdb.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# ## Part 1: Data Manipulation

# %%
# In this dataset, there is a movie with an error in "Released_Year". (Hint: Released_Year should be a 4-digit integer.)
# Find this movie.
imdb[imdb['Released_Year'].str.isdigit()==False]
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966            PG           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
imdb['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
# Correct the values for the corresponding columns ("Release_Year" and "Certificate").
# You may want to look up this movie on www.imdb.com.
# Hint: You can set value for a particular set by: loc[row_name, column_name] = new_value
imdb.loc[966,'Released_Year'] = 1995
imdb.loc[966,'Certificate'] = 'PG'
imdb.loc[966]
# Out:
# Poster_Link      https://m.media-amazon.com/images/M/MV5BNjEzYj...
# Series_Title                                             Apollo 13
# Released_Year                                                 1995
# Certificate                                                     PG
# Runtime                                                    140 min
# Genre                                    Adventure, Drama, History
# IMDB_Rating                                                    7.6
# Overview         NASA must devise a strategy to return Apollo 1...
# Meta_score                                                    77.0
# Director                                                Ron Howard
# Star1                                                    Tom Hanks
# Star2                                                  Bill Paxton
# Star3                                                  Kevin Bacon
# Star4                                                  Gary Sinise
# ...

# %%
# Change "Released_Year" from string to int
imdb['Released_Year'] = imdb['Released_Year'].apply(int)
imdb['Released_Year'].dtype
# Out:
# dtype('int64')

# %%
# Create a new dataframe called "stars" including the following columns:
# Series_Title, Released_Year, Star1, Star2, Star3, Star4
stars = imdb[['Series_Title', 'Released_Year', 'Star1', 'Star2', 'Star3', 'Star4']]
stars
# Out:
#                  Series_Title  Released_Year              Star1  \
# 0    The Shawshank Redemption           1994        Tim Robbins
# 1               The Godfather           1972      Marlon Brando
# 2             The Dark Knight           2008     Christian Bale
# 3      The Godfather: Part II           1974          Al Pacino
# 4                12 Angry Men           1957        Henry Fonda
# ..                        ...            ...                ...
# 995    Breakfast at Tiffany's           1961     Audrey Hepburn
# 996                     Giant           1956   Elizabeth Taylor
# 997     From Here to Eternity           1953     Burt Lancaster
# 998                  Lifeboat           1944  Tallulah Bankhead
# 999              The 39 Steps           1935       Robert Donat
#
#                  Star2           Star3           Star4
# 0       Morgan Freeman      Bob Gunton  William Sadler
# 1            Al Pacino      James Caan    Diane Keaton
# ...

# %%
# Create a new dataframe called "genres" including the following columns:
# Series_Title, Released_Year, Genre.
genres = imdb[['Series_Title', 'Released_Year', 'Genre']]
genres
# Out:
#                  Series_Title  Released_Year                     Genre
# 0    The Shawshank Redemption           1994                     Drama
# 1               The Godfather           1972              Crime, Drama
# 2             The Dark Knight           2008      Action, Crime, Drama
# 3      The Godfather: Part II           1974              Crime, Drama
# 4                12 Angry Men           1957              Crime, Drama
# ..                        ...            ...                       ...
# 995    Breakfast at Tiffany's           1961    Comedy, Drama, Romance
# 996                     Giant           1956            Drama, Western
# 997     From Here to Eternity           1953       Drama, Romance, War
# 998                  Lifeboat           1944                Drama, War
# 999              The 39 Steps           1935  Crime, Mystery, Thriller
#
# [1000 rows x 3 columns]

# %%
# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, Certificate, and gross.
# Sort them in descending order of "Gross"
(
    imdb[(imdb.Released_Year>=2010) & (imdb.IMDB_Rating>=8.5)]
    [['Series_Title','Released_Year','Certificate','Gross']]
    .sort_values('Gross', ascending=False)
)
# Out:
#         Series_Title  Released_Year Certificate        Gross
# 19      Gisaengchung           2019           A   53,367,844
# 33             Joker           2019           A  335,451,311
# 8          Inception           2010          UA  292,576,195
# 21      Interstellar           2014          UA  188,020,017
# 35  The Intouchables           2011          UA   13,182,281
# 34          Whiplash           2014           A   13,092,000
# 18          Hamilton           2020       PG-13          NaN
# 20   Soorarai Pottru           2020           U          NaN

# %%
# Does the sorting result look right to you? What's the problem?

# Answer: Gross is a string type.

# %%
# Resolve this problem of "Gross" and convert its data type to float
# Hint: You may find this webpage useful:
# https://stackoverflow.com/questions/28986489/how-to-replace-text-in-a-column-of-a-pandas-dataframe

imdb['Gross'] = imdb['Gross'].apply(str).str.replace(',','').apply(float)
imdb['Gross']
# Out:
# 0       28341469.0
# 1      134966411.0
# 2      534858444.0
# 3       57300000.0
# 4        4360000.0
#           ...
# 995            NaN
# 996            NaN
# 997     30500000.0
# 998            NaN
# 999            NaN
# Name: Gross, Length: 1000, dtype: float64

# %%
# Next, redo the sorting on Gross

# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, Certificate, and gross.
# Sort them in descending order of "Gross"
(
    imdb[(imdb.Released_Year>=2010) & (imdb.IMDB_Rating>=8.5)]
    [['Series_Title','Released_Year','Certificate','Gross']]
    .sort_values('Gross', ascending=False)
)
# Out:
#         Series_Title  Released_Year Certificate        Gross
# 33             Joker           2019           A  335451311.0
# 8          Inception           2010          UA  292576195.0
# 21      Interstellar           2014          UA  188020017.0
# 19      Gisaengchung           2019           A   53367844.0
# 35  The Intouchables           2011          UA   13182281.0
# 34          Whiplash           2014           A   13092000.0
# 18          Hamilton           2020       PG-13          NaN
# 20   Soorarai Pottru           2020           U          NaN

# %%
# Add a new column "Runtime_min" by removing the string ' min" in "Runtime"
# Set its data type as int

imdb['Runtime_min'] = imdb['Runtime'].str[:-4].astype(int)
imdb['Runtime_min']
# Out:
# 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#       ...
# 995    115
# 996    201
# 997    118
# 998     97
# 999     86
# Name: Runtime_min, Length: 1000, dtype: int64

# %%
# Add a new column "Decade" with values as 1980, 1990, 2000, 2010, 2020, etc.
imdb['Decade'] = imdb['Released_Year'] // 10 * 10
imdb['Decade']
# Out:
# 0      1990
# 1      1970
# 2      2000
# 3      1970
# 4      1950
#        ...
# 995    1960
# 996    1950
# 997    1950
# 998    1940
# 999    1930
# Name: Decade, Length: 1000, dtype: int64

# %% [markdown]
# ## Part 2: Data Summarization
# Done!
#
# ## Part 3: Data Visualization
# Done!
#
# ## Part 4: Tidy Data
#
# After running all cells above, you should have three dataframes:
# - **imdb**
# - **stars**
# - **genres**
#
# Now, let's take a quick look at the three dataframes.

# %%
print(imdb.columns)
imdb.head()
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross',
#        'Runtime_min', 'Decade'],
#       dtype='object')
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title  Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption           1994           A  142 min
# 1             The Godfather           1972           A  175 min
# 2           The Dark Knight           2008          UA  152 min
# 3    The Godfather: Part II           1974           A  202 min
# ...

# %%
print(stars.columns)
stars.head()
# Out:
# Index(['Series_Title', 'Released_Year', 'Star1', 'Star2', 'Star3', 'Star4'], dtype='object')
#                Series_Title  Released_Year           Star1           Star2  \
# 0  The Shawshank Redemption           1994     Tim Robbins  Morgan Freeman
# 1             The Godfather           1972   Marlon Brando       Al Pacino
# 2           The Dark Knight           2008  Christian Bale    Heath Ledger
# 3    The Godfather: Part II           1974       Al Pacino  Robert De Niro
# 4              12 Angry Men           1957     Henry Fonda     Lee J. Cobb
#
#            Star3           Star4
# 0     Bob Gunton  William Sadler
# 1     James Caan    Diane Keaton
# 2  Aaron Eckhart   Michael Caine
# 3  Robert Duvall    Diane Keaton
# 4  Martin Balsam    John Fiedler

# %%
print(genres.columns)
genres.head()
# Out:
# Index(['Series_Title', 'Released_Year', 'Genre'], dtype='object')
#                Series_Title  Released_Year                 Genre
# 0  The Shawshank Redemption           1994                 Drama
# 1             The Godfather           1972          Crime, Drama
# 2           The Dark Knight           2008  Action, Crime, Drama
# 3    The Godfather: Part II           1974          Crime, Drama
# 4              12 Angry Men           1957          Crime, Drama

# %% [markdown]
# Follow the instructions below and write your code to answer the questions:
#
# To better understand the advantages of tidy data, you will first use the "un-tidy" dataframes alone to answer the next few questions:

# %%
# In dataframe "stars", find all movies that star "Morgan Freeman".
# Hint: he could be Star1, Star2, Star3, or Star4.
stars[(stars['Star1'] == 'Morgan Freeman') | (stars['Star2'] == 'Morgan Freeman') | (stars['Star3'] == 'Morgan Freeman') | (stars['Star4'] == 'Morgan Freeman')]
# Out:
#                  Series_Title  Released_Year              Star1  \
# 0    The Shawshank Redemption           1994        Tim Robbins
# 27                      Se7en           1995     Morgan Freeman
# 167                Unforgiven           1992     Clint Eastwood
# 234       Million Dollar Baby           2004       Hilary Swank
# 673                     Glory           1989  Matthew Broderick
# 768       Lucky Number Slevin           2006      Josh Hartnett
# 922            Gone Baby Gone           2007     Morgan Freeman
#
#                  Star2           Star3                Star4
# 0       Morgan Freeman      Bob Gunton       William Sadler
# 27           Brad Pitt    Kevin Spacey  Andrew Kevin Walker
# 167       Gene Hackman  Morgan Freeman       Richard Harris
# 234     Clint Eastwood  Morgan Freeman         Jay Baruchel
# 673  Denzel Washington      Cary Elwes       Morgan Freeman
# 768       Ben Kingsley  Morgan Freeman             Lucy Liu
# ...

# %%
# In dataframe 'stars', who appeared in Star2 the most times? List the top five actors.
stars['Star2'].value_counts().head(5)
# Out:
# Star2
# Emma Watson     7
# Matt Damon      5
# Ian McKellen    4
# Brad Pitt       4
# Kate Winslet    4
# Name: count, dtype: int64

# %%
# In dataframe 'imdb', find all comedies and list Series_Title, Released_Year, Director, and IMDB_Rating
# Sort them by Released_Year in descending order.
# Hint: use .str.contains(...)
imdb[imdb['Genre'].str.contains('Comedy')][['Series_Title','Released_Year','Director','IMDB_Rating']].sort_values(by='Released_Year',ascending=False)
# Out:
#       Series_Title  Released_Year           Director  IMDB_Rating
# 205           Soul           2020        Pete Docter          8.1
# 464    Dil Bechara           2020     Mukesh Chhabra          7.9
# 613           Druk           2020  Thomas Vinterberg          7.8
# 19    Gisaengchung           2019       Bong Joon Ho          8.6
# 128     Chhichhore           2019      Nitesh Tiwari          8.2
# ..             ...            ...                ...          ...
# 318     The Circus           1928    Charles Chaplin          8.1
# 320    The General           1926     Clyde Bruckman          8.1
# 193  The Gold Rush           1925    Charles Chaplin          8.2
# 194   Sherlock Jr.           1924      Buster Keaton          8.2
# 127        The Kid           1921    Charles Chaplin          8.3
#
# [233 rows x 4 columns]

# %%
# In dataframe 'imdb', find all values in the Genre column and the number of occurrences for each value.
# Hint: use value_counts()
imdb['Genre'].value_counts()
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Action, Adventure, Family     1
# Action, Crime, Mystery        1
# Animation, Drama, Romance     1
# Drama, War, Western           1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %% [markdown]
# ### Tidying the data
#
# Next, you will further tidy the two dataframes **stars** and **genres**.
#
# Let's start with **stars**.

# %%
stars.head()
# Out:
#                Series_Title  Released_Year           Star1           Star2  \
# 0  The Shawshank Redemption           1994     Tim Robbins  Morgan Freeman
# 1             The Godfather           1972   Marlon Brando       Al Pacino
# 2           The Dark Knight           2008  Christian Bale    Heath Ledger
# 3    The Godfather: Part II           1974       Al Pacino  Robert De Niro
# 4              12 Angry Men           1957     Henry Fonda     Lee J. Cobb
#
#            Star3           Star4
# 0     Bob Gunton  William Sadler
# 1     James Caan    Diane Keaton
# 2  Aaron Eckhart   Michael Caine
# 3  Robert Duvall    Diane Keaton
# 4  Martin Balsam    John Fiedler

# %%
# Transform the dataframe "stars" to a new dataframe named "stars_long" with the following four columns:
# Series_Title, Released_Year, StarNo (e.g., Star1, Star2, ...), StarName
# Hint: use melt()
#for below to work you must include both series title and released year as the ID variables
stars_long = stars.melt(id_vars=['Series_Title', 'Released_Year'],value_vars=['Star1','Star2','Star3','Star4'],var_name='StarNo',value_name='StarName')
stars_long
# Out:
#                   Series_Title  Released_Year StarNo        StarName
# 0     The Shawshank Redemption           1994  Star1     Tim Robbins
# 1                The Godfather           1972  Star1   Marlon Brando
# 2              The Dark Knight           2008  Star1  Christian Bale
# 3       The Godfather: Part II           1974  Star1       Al Pacino
# 4                 12 Angry Men           1957  Star1     Henry Fonda
# ...                        ...            ...    ...             ...
# 3995    Breakfast at Tiffany's           1961  Star4     Buddy Ebsen
# 3996                     Giant           1956  Star4   Carroll Baker
# 3997     From Here to Eternity           1953  Star4      Donna Reed
# 3998                  Lifeboat           1944  Star4  William Bendix
# 3999              The 39 Steps           1935  Star4  Godfrey Tearle
#
# [4000 rows x 4 columns]

# %%
# Can you transform dataframe 'stars_long' back to its original shape?
# Hint: use pivot()
stars_long.pivot(index=['Series_Title', 'Released_Year'], columns='StarNo', values='StarName')
# Out:
# StarNo                                                    Star1  \
# Series_Title                Released_Year
# (500) Days of Summer        2009                Zooey Deschanel
# 12 Angry Men                1957                    Henry Fonda
# 12 Years a Slave            2013               Chiwetel Ejiofor
# 1917                        2019           Dean-Charles Chapman
# 2001: A Space Odyssey       1968                    Keir Dullea
# ...                                                         ...
# Zootopia                    2016                     Rich Moore
# Zulu                        1964                  Stanley Baker
# Zwartboek                   2006              Carice van Houten
# À bout de souffle           1960             Jean-Paul Belmondo
# Ôkami kodomo no Ame to Yuki 2012                   Aoi Miyazaki
#
# StarNo                                                        Star2  \
# Series_Title                Released_Year
# ...

# %%
# In dataframe "stars_long", find all movies that star "Morgan Freeman".
stars_long[stars_long['StarName'] == 'Morgan Freeman']
# Out:
#                   Series_Title  Released_Year StarNo        StarName
# 27                       Se7en           1995  Star1  Morgan Freeman
# 922             Gone Baby Gone           2007  Star1  Morgan Freeman
# 1000  The Shawshank Redemption           1994  Star2  Morgan Freeman
# 2167                Unforgiven           1992  Star3  Morgan Freeman
# 2234       Million Dollar Baby           2004  Star3  Morgan Freeman
# 2768       Lucky Number Slevin           2006  Star3  Morgan Freeman
# 3673                     Glory           1989  Star4  Morgan Freeman

# %%
# Who appeared in Star2 the most times? List the top five actors.
stars_long[stars_long['StarNo']=='Star2']['StarName'].value_counts().head(5)
# Out:
# StarName
# Emma Watson     7
# Matt Damon      5
# Ian McKellen    4
# Brad Pitt       4
# Kate Winslet    4
# Name: count, dtype: int64

# %%
# Who stars in the most movies in this list? List the top 20 actors.
stars_long['StarName'].value_counts().head(20)
# Out:
# StarName
# Robert De Niro        17
# Tom Hanks             14
# Al Pacino             13
# Clint Eastwood        12
# Brad Pitt             12
# Leonardo DiCaprio     11
# Matt Damon            11
# Christian Bale        11
# James Stewart         10
# Denzel Washington      9
# Johnny Depp            9
# Michael Caine          9
# Scarlett Johansson     9
# Humphrey Bogart        9
# Ethan Hawke            9
# Harrison Ford          8
# Aamir Khan             8
# Jake Gyllenhaal        7
# Jeff Bridges           7
# Bruce Willis           7
# Name: count, dtype: int64

# %%
# Which movie stars had the highest total gross in this movie list? Show the top 10 actors.
# Hint: Join "stars_long" and "imdb"; then group by StarName

stars_gross = pd.merge(stars_long, imdb[['Series_Title', 'Released_Year', 'Gross']],on=['Series_Title', 'Released_Year'],how='inner')
stars_gross.groupby('StarName')['Gross'].sum().sort_values(ascending=False).head(10)
# Out:
# StarName
# Robert Downey Jr.    3.129073e+09
# Tom Hanks            2.903565e+09
# Chris Evans          2.339664e+09
# Joe Russo            2.205039e+09
# Mark Ruffalo         2.058396e+09
# Leonardo DiCaprio    2.049297e+09
# Ian McKellen         1.869869e+09
# Daniel Radcliffe     1.835901e+09
# Rupert Grint         1.835901e+09
# Matt Damon           1.728542e+09
# Name: Gross, dtype: float64

# %%
# Find the best director-actor duos
# i.e., director-actor pairs that collaborated in at least five movies,
# sort them in descending order of average IMDB_Rating
# Hint: Join imdb and stars_long; group by ['Director','StarName']

# Join imdb and stars_long
director_actor_duos = pd.merge(imdb[['Series_Title', 'Released_Year', 'Director', 'IMDB_Rating']],
    stars_long[['Series_Title', 'Released_Year', 'StarName']],
    on=['Series_Title', 'Released_Year'],
    how='inner'
)

# Group by Director and StarName and calculate collaboration count and average IMDB_Rating
duo_stats = director_actor_duos.groupby(['Director', 'StarName']).agg(collaboration_count=('Series_Title', 'count'),
average_imdb_rating=('IMDB_Rating', 'mean'))

# Filter for duos with at least five collaborations and sort by average IMDB_Rating
duo_stats[duo_stats['collaboration_count'] >= 5].sort_values(by='average_imdb_rating', ascending=False)
# Out:
#                                    collaboration_count  average_imdb_rating
# Director          StarName
# Peter Jackson     Ian McKellen                       5             8.400000
# Charles Chaplin   Charles Chaplin                    6             8.333333
# Akira Kurosawa    Toshirô Mifune                     7             8.242857
# Martin Scorsese   Robert De Niro                     6             8.183333
# Akira Kurosawa    Tatsuya Nakadai                    5             8.180000
# Richard Linklater Ethan Hawke                        5             7.960000
# Clint Eastwood    Clint Eastwood                     5             7.960000
# Woody Allen       Woody Allen                        5             7.840000
# Joel Coen         Ethan Coen                         6             7.816667

# %%
stars_long.head()
# Out:
#                Series_Title  Released_Year StarNo        StarName
# 0  The Shawshank Redemption           1994  Star1     Tim Robbins
# 1             The Godfather           1972  Star1   Marlon Brando
# 2           The Dark Knight           2008  Star1  Christian Bale
# 3    The Godfather: Part II           1974  Star1       Al Pacino
# 4              12 Angry Men           1957  Star1     Henry Fonda

# %%
# Bonus question
# Who did "Amy Adams" co-star with in this movie list?
# Hint: Join stars_long with itself to find pairs of co-stars

#I only wrote the join piece, I don't really know how the _x and _y is helping to find

co_stars = pd.merge(
    stars_long[['Series_Title', 'Released_Year', 'StarNo', 'StarName']],
    stars_long[['Series_Title', 'Released_Year', 'StarNo', 'StarName']],
    on=['Series_Title', 'Released_Year'],
    how='inner',
    suffixes=('_x', '_y')
)

# Filter for Amy Adams and her co-stars in the same movie
amy_adams_co_stars = co_stars[
    (co_stars['StarName_x'] == 'Amy Adams') &
    (co_stars['StarName_y'] != 'Amy Adams') &
    (co_stars['StarNo_x'] != co_stars['StarNo_y'])
]


# this is Gemini's explanation

# Select relevant columns and drop duplicates to get unique co-star pairs
# To avoid duplicates like (Actor1, Actor2) and (Actor2, Actor1), we can sort the star names
# and then drop duplicates. However, for this specific question asking for 'Amy Adams' co-stars,
# we just need to list the other star.

unique_co_stars_with_amy = amy_adams_co_stars[['Series_Title', 'Released_Year', 'StarName_y']].drop_duplicates()

unique_co_stars_with_amy
# Out:
#       Series_Title  Released_Year          StarName_y
# 1905       Arrival           2016       Jeremy Renner
# 1906       Arrival           2016     Forest Whitaker
# 1907       Arrival           2016   Michael Stuhlbarg
# 5364           Her           2013     Joaquin Phoenix
# 5366           Her           2013  Scarlett Johansson
# 5367           Her           2013         Rooney Mara
# 10456  The Fighter           2010       Mark Wahlberg
# 10457  The Fighter           2010      Christian Bale
# 10459  The Fighter           2010         Melissa Leo

# %% [markdown]
# Next, let's reshape the dataframe **genres**, which is a little bit more complicated.

# %%
genres.head()
# Out:
#                Series_Title  Released_Year                 Genre
# 0  The Shawshank Redemption           1994                 Drama
# 1             The Godfather           1972          Crime, Drama
# 2           The Dark Knight           2008  Action, Crime, Drama
# 3    The Godfather: Part II           1974          Crime, Drama
# 4              12 Angry Men           1957          Crime, Drama

# %%
# Step 1: Split the 'Genre' string by ', ' into a list of individual genres and expand them to different columns
genres_split = genres['Genre'].str.split(', ', expand=True)
genres_split
# Out:
#           0        1         2
# 0     Drama     None      None
# 1     Crime    Drama      None
# 2    Action    Crime     Drama
# 3     Crime    Drama      None
# 4     Crime    Drama      None
# ..      ...      ...       ...
# 995  Comedy    Drama   Romance
# 996   Drama  Western      None
# 997   Drama  Romance       War
# 998   Drama      War      None
# 999   Crime  Mystery  Thriller
#
# [1000 rows x 3 columns]

# %%
# Step 2: Rename the columns as: Genre1, Genre2, Genre3
genres_split.columns = ['Genre1', 'Genre2', 'Genre3']
genres_split.head()
# Out:
#    Genre1 Genre2 Genre3
# 0   Drama   None   None
# 1   Crime  Drama   None
# 2  Action  Crime  Drama
# 3   Crime  Drama   None
# 4   Crime  Drama   None

# %%
# Step 3: Combine ['Series_Title','Released_Year'] in 'genres' and ['Genre1','Genre2','Genre3'] in 'genres_split'.
# Save it to a new dataframe named 'genres_wide'.
# Hint: Use pd.concat(...)
genres_wide = pd.concat([genres, genres_split], axis=1)
genres_wide
# Out:
#                  Series_Title  Released_Year                     Genre  \
# 0    The Shawshank Redemption           1994                     Drama
# 1               The Godfather           1972              Crime, Drama
# 2             The Dark Knight           2008      Action, Crime, Drama
# 3      The Godfather: Part II           1974              Crime, Drama
# 4                12 Angry Men           1957              Crime, Drama
# ..                        ...            ...                       ...
# 995    Breakfast at Tiffany's           1961    Comedy, Drama, Romance
# 996                     Giant           1956            Drama, Western
# 997     From Here to Eternity           1953       Drama, Romance, War
# 998                  Lifeboat           1944                Drama, War
# 999              The 39 Steps           1935  Crime, Mystery, Thriller
#
#      Genre1   Genre2    Genre3
# 0     Drama     None      None
# 1     Crime    Drama      None
# ...

# %%
# Step 4: Transform genres_wide to a new dataframe genres_long with the following four columns:
# Series_Title, Released_Year, GenreNo (e.g., Genre1, Genre2, Genre3), GenreName
# Hint: use melt()
genres_long = genres_wide.melt(id_vars=['Series_Title', 'Released_Year'], value_vars=['Genre1', 'Genre2', 'Genre3'], var_name='GenreNo', value_name='GenreName')
genres_long
# Out:
#                   Series_Title  Released_Year GenreNo GenreName
# 0     The Shawshank Redemption           1994  Genre1     Drama
# 1                The Godfather           1972  Genre1     Crime
# 2              The Dark Knight           2008  Genre1    Action
# 3       The Godfather: Part II           1974  Genre1     Crime
# 4                 12 Angry Men           1957  Genre1     Crime
# ...                        ...            ...     ...       ...
# 2995    Breakfast at Tiffany's           1961  Genre3   Romance
# 2996                     Giant           1956  Genre3      None
# 2997     From Here to Eternity           1953  Genre3       War
# 2998                  Lifeboat           1944  Genre3      None
# 2999              The 39 Steps           1935  Genre3  Thriller
#
# [3000 rows x 4 columns]

# %%
# How many unique genres (atomic values, e.g., Drama, Comedy, ...) are there?
# How many movies are there for each genre?
genres_long['GenreName'].nunique() #21
genres_long['GenreName'].value_counts().dropna()
# Out:
# GenreName
# Drama        724
# Comedy       233
# Crime        209
# Adventure    196
# Action       189
# Thriller     137
# Romance      125
# Biography    109
# Mystery       99
# Animation     82
# Sci-Fi        67
# Fantasy       66
# Family        56
# History       56
# War           51
# Music         35
# Horror        32
# Western       20
# Film-Noir     19
# Sport         19
# Musical       17
# Name: count, dtype: int64

# %%
# What is the average IMDB rating for each genre?
# Sort the genres in descending order of average IMDB_Rating.
# Hint: join imdb with genres_long; group by GenreName

genre_imdb_ratings = pd.merge(
    imdb[['Series_Title', 'Released_Year', 'IMDB_Rating']],
    genres_long[['Series_Title', 'Released_Year', 'GenreName']],
    on=['Series_Title', 'Released_Year'],
    how='inner')

# Group by GenreName and calculate the average IMDB_Rating, then sort
genre_average_ratings = genre_imdb_ratings.groupby('GenreName')['IMDB_Rating'].mean().sort_values(ascending=False)
genre_average_ratings
# Out:
# GenreName
# War          8.013725
# Western      8.000000
# Film-Noir    7.989474
# Sci-Fi       7.977612
# Mystery      7.967677
# Drama        7.959392
# Crime        7.954545
# History      7.953571
# Adventure    7.952041
# Action       7.948677
# Musical      7.947059
# Biography    7.935780
# Fantasy      7.931818
# Animation    7.930488
# Sport        7.926316
# Romance      7.925600
# Music        7.914286
# Family       7.912500
# Thriller     7.909489
# Comedy       7.903433
# Horror       7.887500
# Name: IMDB_Rating, dtype: float64

# %%
# Who is the "King of Comedy" (i.e., the actor who starred in the most comedy movies)?
# Hint: find all comedies in genres_long ; join with stars_long; group by StarName

#Find  comedies in genres_long
comedy_genres = genres_long[genres_long['GenreName'] == 'Comedy'].dropna(subset=['GenreName'])

#Join with stars_long
comedy_stars = pd.merge(
    comedy_genres,
    stars_long,
    on=['Series_Title', 'Released_Year'],
    how='inner'
)

#Group by StarName and count the number of comedy movies, show the top 1
comedy_king = comedy_stars['StarName'].value_counts().head(1)
comedy_king
# Out:
# StarName
# Bill Murray    6
# Name: count, dtype: int64

# %%
# Who are the best action stars?
# i.e., the actors who star in at least 5 action movies, sorted by average IMDB rating in descending order
# Hint: You need to join columns from all three dataframes: imdb, stars_long, genres_long
action_genres = genres_long[genres_long['GenreName'] == 'Action'].dropna(subset=['GenreName'])

# Join action_genres with stars_long
action_stars_df = pd.merge(
    action_genres[['Series_Title', 'Released_Year', 'GenreName']],
    stars_long,
    on=['Series_Title', 'Released_Year'],
    how='inner')

# Join the result with imdb to get IMDB_Rating
action_stars_with_ratings = pd.merge(
    action_stars_df,
    imdb[['Series_Title', 'Released_Year', 'IMDB_Rating']],
    on=['Series_Title', 'Released_Year'],
    how='inner')

# Group by StarName, count movies, and calculate average IMDB_Rating
best_action_stars = action_stars_with_ratings.groupby('StarName').agg(
    action_movie_count=('Series_Title', 'count'),
    average_imdb_rating=('IMDB_Rating', 'mean'))

# Filter for stars with at least 5 action movies and sort by average IMDB rating
best_action_stars = best_action_stars[best_action_stars['action_movie_count'] >= 5].sort_values(by='average_imdb_rating', ascending=False)

best_action_stars
# Out:
#                    action_movie_count  average_imdb_rating
# StarName
# Harrison Ford                       8             8.262500
# Christian Bale                      6             8.183333
# Tom Hardy                           5             8.100000
# Robert Downey Jr.                   6             8.016667

# %%
# Create a pivot table to show the number of movies of different genres in different decades.
# Row: GenreName
# Column: Decade
# Hint: https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# Merge genres_long with imdb to get the 'Decade' column
genres_with_decade = pd.merge(genres_long,
    imdb[['Series_Title', 'Released_Year', 'Decade']],
    on=['Series_Title', 'Released_Year'],
    how='left')

# Create the pivot table
genre_decade_pivot = genres_with_decade.pivot_table(
    index='GenreName',
    columns='Decade',
    aggfunc='size', # Use 'size' to count the number of movies
)

genre_decade_pivot
# Out:
# Decade     1920  1930  1940  1950  1960  1970  1980   1990   2000   2010  2020
# GenreName
# Action      2.0   2.0   3.0   2.0  11.0  11.0  20.0   22.0   54.0   62.0   NaN
# Adventure   2.0   4.0   3.0   9.0  11.0  14.0  22.0   17.0   52.0   61.0   1.0
# Animation   NaN   NaN   1.0   NaN   1.0   3.0   8.0   18.0   22.0   28.0   1.0
# Biography   1.0   NaN   NaN   NaN   9.0  10.0   9.0   15.0   27.0   37.0   1.0
# Comedy      5.0   9.0   9.0   8.0  11.0  17.0  26.0   38.0   46.0   61.0   3.0
# Crime       NaN   4.0   8.0  14.0   9.0  19.0  13.0   45.0   53.0   44.0   NaN
# Drama       6.0  12.0  25.0  47.0  51.0  49.0  54.0  113.0  182.0  180.0   5.0
# Family      1.0   3.0   3.0   NaN   4.0   5.0   6.0   10.0   16.0    8.0   NaN
# Fantasy     2.0   1.0   2.0   2.0   2.0   4.0  11.0   10.0   21.0   11.0   NaN
# Film-Noir   NaN   NaN  11.0   8.0   NaN   NaN   NaN    NaN    NaN    NaN   NaN
# History     2.0   1.0   1.0   3.0   7.0   4.0   8.0    6.0   11.0   11.0   2.0
# ...
